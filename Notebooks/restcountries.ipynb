# %%
#
# Get Data from Countries REST API
# June 10th, 2019 by Ali Jabbari
#

# %%
import requests
import json
import pandas as pd

import re
import pickle
import csv

from pandas.io.json import json_normalize

# %%
data_path = '/mnt/c/users/alija/Datasets/'

# %% [markdown]
# **Constructing Country Currencies (En/Fr) Database**

# %%
def get_info(fields):
    currencies_list = []
    country_list = []
    base_url = "https://restcountries.eu/rest/v2/all?fields="
    try:
        fields_str = ';'.join(fields)
        url = base_url + fields_str
        response = (requests.get(url).text)
        response_json = json.loads(response)
        for item in response_json:
            currencies_list.extend(item['currencies'])
            country_list.append(item['name'])
        return response_json
    
    except Exception as e:
        raise e

# %%
data = get_info(['name','currencies', 'alpha3Code', 'translations'])
df = json_normalize(data, meta=['name', 'alpha3Code', 'translations'], record_path=['currencies'], record_prefix='currency_')

df.head()
# Out:
#   currency_code        currency_name currency_symbol            name  \
# 0           AFN       Afghan afghani               ؋     Afghanistan
# 1           EUR                 Euro               €   Åland Islands
# 2           ALL         Albanian lek               L         Albania
# 3           DZD       Algerian dinar             د.ج         Algeria
# 4           USD  United State Dollar               $  American Samoa
#
#   alpha3Code                                       translations
# 0        AFG  {'br': 'Afeganistão', 'pt': 'Afeganistão', 'nl...
# 1        ALA  {'br': 'Ilhas de Aland', 'pt': 'Ilhas de Aland...
# 2        ALB  {'br': 'Albânia', 'pt': 'Albânia', 'nl': 'Alba...
# 3        DZA  {'br': 'Argélia', 'pt': 'Argélia', 'nl': 'Alge...
# 4        ASM  {'br': 'Samoa Americana', 'pt': 'Samoa America...

# %%
df_trans = df['translations'].apply(pd.Series)
df = pd.concat([df, df_trans], axis = 1).drop('translations', axis = 1)

df1 = df[['alpha3Code', 'name', 'fr', 'currency_code', 'currency_symbol', 'currency_name']]
df1.rename(columns={'name':'country_name_en', 'fr':'country_name_fr', 'currency_name':'currency_name_en'}, inplace=True)
#df1['country_name_fr'] = df1['country_name_fr'].apply(lambda x: str(x)[:-1])

df1.head()
# Out:
#   alpha3Code country_name_en    country_name_fr currency_code currency_symbol  \
# 0        AFG     Afghanistan        Afghanistan           AFN               ؋
# 1        ALA   Åland Islands              Åland           EUR               €
# 2        ALB         Albania            Albanie           ALL               L
# 3        DZA         Algeria            Algérie           DZD             د.ج
# 4        ASM  American Samoa  Samoa américaines           USD               $
#
#       currency_name_en
# 0       Afghan afghani
# 1                 Euro
# 2         Albanian lek
# 3       Algerian dinar
# 4  United State Dollar

# %%
df1[df1['country_name_en']=='Cook Islands']
# Out:
#    alpha3Code country_name_en country_name_fr currency_code currency_symbol  \
# 61        COK    Cook Islands       Îles Cook           NZD               $
# 62        COK    Cook Islands       Îles Cook           CKD               $
#
#        currency_name_en
# 61   New Zealand dollar
# 62  Cook Islands dollar

# %%
df2 = pd.read_csv('../../DATA/devises.csv', names=['county_name_fr', 'currency_name_fr', 'currency_code', 'code_num'], delimiter='\t')
df2['currency_code'] = df2['currency_code'].apply(lambda x: str(x)[:-1])
df2 = df2[['currency_code', 'currency_name_fr']]
df2.head(10)
# Out:
#   currency_code                 currency_name_fr
# 0           AFN                         Afghani
# 1           ZAR                            Rand
# 2           ALL                             Lek
# 3           DZD                  Dinar algérien
# 4           EUR                            Euro
# 5           EUR                            Euro
# 6           AOA                          Kwanza
# 7           XCD  Dollar des Caraïbes orientales
# 8            na       Pas de devise universelle
# 9           XCD  Dollar des Caraïbes orientales

# %%
result = pd.merge(df1, df2, on='currency_code')
result = result.drop_duplicates().reset_index()
result.sort_values(by ='alpha3Code')
# Out:
#      index alpha3Code                       country_name_en  \
# 87    1811        ABW                                 Aruba
# 0        0        AFG                           Afghanistan
# 60    1644        AGO                                Angola
# 61    1645        AIA                              Anguilla
# 1        1        ALA                         Åland Islands
# 37    1261        ALB                               Albania
# 2       36        AND                               Andorra
# 261   2124        ARE                  United Arab Emirates
# 85    1809        ARG                             Argentina
# 86    1810        ARM                               Armenia
# 40    1264        ASM                        American Samoa
# 69    1709        ATA                            Antarctica
# 78    1781        ATA                            Antarctica
# 10     316        ATF           French Southern Territories
# 62    1653        ATG                   Antigua and Barbuda
# 70    1717        AUS                             Australia
# 3       71        AUT                               Austria
# 88    1812        AZE                            Azerbaijan
# 121   1910        BDI                               Burundi
# 4      106        BEL                               Belgium
# 95    1819        BEN                                 Benin
# 41    1283        BES      Bonaire, Sint Eustatius and Saba
# 96    1827        BFA                          Burkina Faso
# 91    1815        BGD                            Bangladesh
# 120   1909        BGR                              Bulgaria
# 90    1814        BHR                               Bahrain
# 89    1813        BHS                               Bahamas
# 109   1892        BIH                Bosnia and Herzegovina
# 29     981        BLM                      Saint Barthélemy
# 93    1817        BLR                               Belarus
# ..     ...        ...                                   ...
# 257   2120        TUR                                Turkey
# 77    1773        TUV                                Tuvalu
# 250   2113        TWN                                Taiwan
# 252   2115        TZA          Tanzania, United Republic of
# 259   2122        UGA                                Uganda
# 260   2123        UKR                               Ukraine
# 43    1321        UMI  United States Minor Outlying Islands
# 262   2125        URY                               Uruguay
# 58    1606        USA              United States of America
# 263   2126        UZB                            Uzbekistan
# 14     456        VAT                              Holy See
# 68    1701        VCT      Saint Vincent and the Grenadines
# 265   2128        VEN    Venezuela (Bolivarian Republic of)
# 44    1340        VGB              Virgin Islands (British)
# 45    1359        VIR                 Virgin Islands (U.S.)
# 266   2129        VNM                              Viet Nam
# 264   2127        VUT                               Vanuatu
# 162   2013        WLF                     Wallis and Futuna
# 234   2097        WSM                                 Samoa
# 267   2130        YEM                                 Yemen
# 193   2050        ZAF                          South Africa
# 268   2131        ZMB                                Zambia
# 182   2035        ZWE                              Zimbabwe
# 111   1894        ZWE                              Zimbabwe
# 107   1889        ZWE                              Zimbabwe
# 84    1805        ZWE                              Zimbabwe
# 59    1625        ZWE                              Zimbabwe
# 36    1226        ZWE                              Zimbabwe
# 194   2053        ZWE                              Zimbabwe
# 134   1953        ZWE                              Zimbabwe
#
#                                  country_name_fr currency_code  \
# 87                                         Aruba           AWG
# 0                                    Afghanistan           AFN
# 60                                        Angola           AOA
# 61                                      Anguilla           XCD
# 1                                          Åland           EUR
# 37                                       Albanie           ALL
# 2                                        Andorre           EUR
# 261                          Émirats arabes unis           AED
# 85                                     Argentine           ARS
# 86                                       Arménie           AMD
# 40                             Samoa américaines           USD
# 69                                   Antarctique           AUD
# 78                                   Antarctique           GBP
# 10   Terres australes et antarctiques françaises           EUR
# 62                            Antigua-et-Barbuda           XCD
# 70                                     Australie           AUD
# 3                                       Autriche           EUR
# 88                                   Azerbaïdjan           AZN
# 121                                      Burundi           BIF
# 4                                       Belgique           EUR
# 95                                         Bénin           XOF
# 41               Bonaire, Saint-Eustache et Saba           USD
# 96                                  Burkina Faso           XOF
# 91                                    Bangladesh           BDT
# 120                                     Bulgarie           BGN
# 90                                       Bahreïn           BHD
# 89                                       Bahamas           BSD
# 109                           Bosnie-Herzégovine           BAM
# 29                              Saint-Barthélemy           EUR
# 93                                   Biélorussie           BYR
# ..                                           ...           ...
# 257                                      Turquie           TRY
# 77                                        Tuvalu           AUD
# 250                                       Taïwan           TWD
# 252                                     Tanzanie           TZS
# 259                                       Uganda           UGX
# 260                                      Ukraine           UAH
# 43        Îles mineures éloignées des États-Unis           USD
# 262                                      Uruguay           UYU
# 58                                    États-Unis           USD
# 263                                  Ouzbékistan           UZS
# 14                                    voir Saint           EUR
# 68               Saint-Vincent-et-les-Grenadines           XCD
# 265                                    Venezuela           VEF
# 44                     Îles Vierges britanniques           USD
# 45                   Îles Vierges des États-Unis           USD
# 266                                     Viêt Nam           VND
# 264                                      Vanuatu           VUV
# 162                             Wallis-et-Futuna           XPF
# 234                                        Samoa           WST
# 267                                        Yémen           YER
# 193                               Afrique du Sud           ZAR
# 268                                       Zambie           ZMW
# 182                                     Zimbabwe           JPY
# 111                                     Zimbabwe           BWP
# 107                                     Zimbabwe           INR
# 84                                      Zimbabwe           GBP
# 59                                      Zimbabwe           USD
# 36                                      Zimbabwe           EUR
# 194                                     Zimbabwe           ZAR
# 134                                     Zimbabwe           CNY
#
#     currency_symbol                         currency_name_en  \
# 87                ƒ                            Aruban florin
# 0                 ؋                           Afghan afghani
# 60               Kz                           Angolan kwanza
# 61                $                    East Caribbean dollar
# 1                 €                                     Euro
# 37                L                             Albanian lek
# 2                 €                                     Euro
# 261             د.إ              United Arab Emirates dirham
# 85                $                           Argentine peso
# 86              NaN                            Armenian dram
# 40                $                      United State Dollar
# 69                $                        Australian dollar
# 78                £                            British pound
# 10                €                                     Euro
# 62                $                    East Caribbean dollar
# 70                $                        Australian dollar
# 3                 €                                     Euro
# 88              NaN                        Azerbaijani manat
# 121              Fr                          Burundian franc
# 4                 €                                     Euro
# 95               Fr                   West African CFA franc
# 41                $                     United States dollar
# 96               Fr                   West African CFA franc
# 91                ৳                         Bangladeshi taka
# 120              лв                            Bulgarian lev
# 90             .د.ب                           Bahraini dinar
# 89                $                          Bahamian dollar
# 109             NaN  Bosnia and Herzegovina convertible mark
# 29                €                                     Euro
# 93               Br                     Old Belarusian ruble
# ..              ...                                      ...
# 257             NaN                             Turkish lira
# 77                $                        Australian dollar
# 250               $                        New Taiwan dollar
# 252              Sh                       Tanzanian shilling
# 259              Sh                         Ugandan shilling
# 260               ₴                        Ukrainian hryvnia
# 43                $                     United States Dollar
# 262               $                           Uruguayan peso
# 58                $                     United States dollar
# 263             NaN                         Uzbekistani so'm
# 14                €                                     Euro
# 68                $                    East Caribbean dollar
# 265            Bs F                       Venezuelan bolívar
# 44                $                     United States dollar
# 45                $                     United States dollar
# 266               ₫                          Vietnamese đồng
# 264              Vt                             Vanuatu vatu
# 162              Fr                                CFP franc
# 234               T                              Samoan tālā
# 267               ﷼                              Yemeni rial
# 193               R                       South African rand
# 268              ZK                           Zambian kwacha
# 182               ¥                             Japanese yen
# 111               P                            Botswana pula
# 107               ₹                             Indian rupee
# 84                £                            British pound
# 59                $                     United States dollar
# 36                €                                     Euro
# 194              Rs                       South African rand
# 134               ¥                             Chinese yuan
#
#                     currency_name_fr
# 87                   Florin arubais
# 0                           Afghani
# 60                           Kwanza
# 61   Dollar des Caraïbes orientales
# 1                              Euro
# 37                              Lek
# 2                              Euro
# 261                      Dirham UAE
# 85                    Peso Argentin
# 86                    Dram Armenien
# 40                        Dollar US
# 69                Dollar Australien
# 78                   Livre Sterling
# 10                             Euro
# 62   Dollar des Caraïbes orientales
# 70                Dollar Australien
# 3                              Euro
# 88             Manat azerbaïdjanais
# 121                   Franc Burundi
# 4                              Euro
# 95                  Franc CFA BCEAO
# 41                        Dollar US
# 96                  Franc CFA BCEAO
# 91                             Taka
# 120                     Lev Bulgare
# 90                   Dinar Bahraini
# 89                  Dollar Bahaméen
# 109                Mark Convertible
# 29                             Euro
# 93                Rouble Biélorusse
# ..                               ...
# 257                    Livre Turque
# 77                Dollar Australien
# 250        Nouveau dollar de Taïwan
# 252              Shilling Tanzanien
# 259              Shilling Ougandais
# 260                         Hryvnia
# 43                        Dollar US
# 262                  Peso Uruguayen
# 58                        Dollar US
# 263                Sum d'Oubekistan
# 14                             Euro
# 68   Dollar des Caraïbes orientales
# 265                         Bolivar
# 44                        Dollar US
# 45                        Dollar US
# 266                            Dong
# 264                            Vatu
# 162                       Franc CFP
# 234                            Tala
# 267                  Riyal yéménite
# 193                            Rand
# 268                  Kwacha Zambien
# 182                             Yen
# 111                            Pula
# 107                 Roupie Indienne
# 84                   Livre Sterling
# 59                        Dollar US
# 36                             Euro
# 194                            Rand
# 134                   Yuan Renminbi
#
# [269 rows x 8 columns]

# %%
out_df = result[['alpha3Code','country_name_en','country_name_fr','currency_code','currency_symbol','currency_name_en','currency_name_fr']]
out_df.head()
# Out:
#   alpha3Code country_name_en country_name_fr currency_code currency_symbol  \
# 0        AFG     Afghanistan     Afghanistan           AFN               ؋
# 1        ALA   Åland Islands           Åland           EUR               €
# 2        AND         Andorra         Andorre           EUR               €
# 3        AUT         Austria        Autriche           EUR               €
# 4        BEL         Belgium        Belgique           EUR               €
#
#   currency_name_en currency_name_fr
# 0   Afghan afghani         Afghani
# 1             Euro            Euro
# 2             Euro            Euro
# 3             Euro            Euro
# 4             Euro            Euro

# %%
out_df.to_csv('currencies_en_fr.csv', index=False)

# %% [markdown]
# ** Keywords population **

# %%
df = out_df
cur_set = set(df['currency_name_fr'])

# %%
cur_list = [str(x)[:-1] for x in cur_set]
cur_alias = ['Dollar américain', 'Renminbi', 'monnaie unique européenne', 'monnaie européenne']
cur_list += cur_alias

# %%
prefix = ['Nouveau']
cur_roots = []
suffix = []
for cur in cur_list:
    kw = cur.split()
    if kw[0] in prefix:
        cur_roots.append(kw[1])
        suffix.append(' '.join(kw[2:]))
    else:
        cur_roots.append(kw[0])
        suffix.append(' '.join(kw[1:]))

# %%
roots_vars = [''.join([cur,'s']) for cur in cur_roots]
suffix_vars = [sx if sx.startswith(("des ","d'",'de ', 'du ')) or sx.endswith(('s','x')) or sx.isupper() or len(sx)==0 else ''.join([sx, 's']) for sx in suffix]
cur_pl = [' '.join([a,b]) if len(b) > 0 else ''.join([a,b]) for a,b in zip(roots_vars, suffix_vars)]

# %%
cur_vars = cur_list + cur_pl + cur_roots + roots_vars
cur_vars.sort()

# %%
cur_codes = list(set(df['currency_code']))
cur_symbs = list(set(df['currency_symbol']))

# %% [markdown]
# **Load/Extract Sentences in Text Corpus**

# %%
# split text into sentences
def extractSentences(txtsrc):
    sentences =[]

    with open(txtsrc, "rb") as infile:
        text = pickle.load(infile)

    for item in text:
        sentences.extend(re.split(r' *[\.\?!][\'"\)\]]* *', item))

    with open("allsents.txt", "wb") as outfile:
        pickle.dump(sentences, outfile)
    
    return sentences

# Load sentences from file (e.g. 'allsents.txt')
def loadPickled(pickle_file):
    with open(pickle_file, 'rb') as fp:
        array = pickle.load(fp)
    return array

# Find corresponding elements in list
def findAll(lst, predicate):
    return [i for i in lst if predicate(i)]

#  Examine the generated annotations
def examAnns(anns):
    for item in anns:
        print(item[0], ':', [item[0][a:b] for (a,b,c) in item[1]['entities']])

# %%
# %%time

sentences = loadPickled(data_path + 'allsents.txt')
# Out:
# CPU times: user 19.2 s, sys: 44.6 s, total: 1min 3s
# Wall time: 1min 4s

# %%
sentences = [x for x in sentences if x]

# %% [markdown]
# ** Find Mentions in sentences **

# %%
import annotator
cur_codes = [' USD ', ' GBP ', ' EUR ', ' CHF ', ' CNY ', ' KR ', ' JPY ', ' AUD ', ' CAD ']
cur_symbs = ['$', '€', '¥', '£']
curs = [' '+s.upper()+' ' for s in cur_vars] # spaces to avoid words containing currency related terms
keywords = set(cur_codes + cur_symbs + curs)

# %%
keywords

# %%
# A duré 2 jours avec pickle 15-17 juin

label = 'CUR'
annotations = annotator.annotateText(sentences, keywords, label)

# %%
# %%time
with open(data_path +label+ "_annotations.txt", "wb") as outfile:
    pickle.dump(annotations, outfile)

# %%
# CUR_annotations = loadPickled(data_path+'CUR_annotations.txt')
